# %% [markdown]
# Given the same dataset,
#
# - extract the most syntactically weighted N-grams, omitting nonsense (‘казалось бы’, ‘возможно предположить’, etc). The main idea is to extract the most valuable data from the text.
#
# - Try different models for a topic extraction. Which one performs better? What metrics were used to evaluate the model?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sbn
import re
import multiprocessing as mp
from string import punctuation
import gensim

# %% [markdown]
# Load data:

# %%
lenta_data = pd.read_csv('E:/PycharmProjects/data/lenta-ru-news.csv')
lenta_data.head()
# Out:
# c:\program files\python38\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                            url  \
# 0   https://lenta.ru/news/1914/09/16/hungarnn/
# 1  https://lenta.ru/news/1914/09/16/lermontov/
# 2  https://lenta.ru/news/1914/09/17/nesteroff/
# 3   https://lenta.ru/news/1914/09/17/bulldogn/
# 4       https://lenta.ru/news/1914/09/18/zver/
#
#                                                title  \
# 0  1914. Русские войска вступили в пределы Венгрии
# 1  1914. Празднование столетия М.Ю. Лермонтова от...
# 2                           1914. Das ist Nesteroff!
# 3                    1914. Бульдог-гонец под Льежем
# 4           1914. Под Люблином пойман швабский зверь
#
#                                                 text       topic  \
# 0  Бои у Сопоцкина и Друскеник закончились отступ...  Библиотека
# 1  Министерство народного просвещения, в виду про...  Библиотека
# 2  Штабс-капитан П. Н. Нестеров на днях, увидев в...  Библиотека
# 3  Фотограф-корреспондент Daily Mirror рассказыва...  Библиотека
# 4  Лица, приехавшие в Варшаву из Люблина, передаю...  Библиотека
#
#              tags        date
# 0  Первая мировая  1914/09/16
# 1  Первая мировая  1914/09/16
# 2  Первая мировая  1914/09/17
# 3  Первая мировая  1914/09/17
# 4  Первая мировая  1914/09/18

# %% [markdown]
# Clean and preprocessing text data:

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ситилинк\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
import re, string
from nltk.stem.snowball import SnowballStemmer

russian_stopwords = stopwords.words("russian")
russian_stopwords.extend(['BBC', 'ВВС', 'РИА', 'Риа','риа', 'пресс центра', 'агенства','прайм тасс', 'ТАСС', 
                          'Интерфакс', 'Интерфакса', 'новости','пресс службы', 'интерфакс', 'интерфакса', 'мнен', 'дан'
                          'Таким образом', 'как', 'по', 'в', 'результате', 'В', 'В результате', 'мнению', 'данным',
                          'таким образом', 'согласно которым', 'до сих пор', 'понедельник', 'вторник', 'рбк', 'РБК', 
                          'итартасс', 'ссыл', 'ссылается', 'день', 'ночь', 'утро', 'вечер', 'Reuters',
                          'наст', 'врем', 'ссылк', 'сообщ', 'агенств', 'сих', 'пор',
                          'среда', 'четверг', 'пятница', 'суббота', 'воскресенье', 'лет', 'год', 'некотор', 'необход', 
                          'лиш', "владимир",'Associated Press',
                          'сказ', 'больш', "ЕЭС России", 'eэс', 'Associated', 'соответств', 'говор', 'лучш', 'сообща',
                          'новост', 'эх'
                         ])
regex = re.compile('[%s]' % re.escape(string.punctuation))
stemmer = SnowballStemmer("russian") 

def preprocessing(text):
    text = regex.sub('', text)
    text = [token for token in text.split() if token not in russian_stopwords]
    text = [stemmer.stem(token) for token in text] 
    text = [token for token in text if token not in russian_stopwords]
    text = [token for token in text if token] 
    return ' '.join(text)

# %% [markdown]
# Only 100 000 values from dataset, bcs original dataset is very big and process it take a lot of time:

# %%
lenta_data['text'][:100000] = lenta_data['text'][:100000].apply(lambda x: preprocessing(x))

# %%
preprocessing_data = pd.DataFrame({'text': lenta_data['text'][:100000]})
preprocessing_data
# Out:
#                                                     text
# 0      бо сопоцкин друскеник законч отступлен германц...
# 1      министерств народн просвещен вид происходя чре...
# 2      штабскапита п н нестер днях увид район желтиев...
# 3      фотографкорреспондент Daily Mirror рассказыва ...
# 4      лиц приеха варшав люблин переда туд доставл «ш...
# ...                                                  ...
# 99995
# 99996  истека установлен законодательств рф двухмесяч...
# 99997  исследован независим групп учен швец канад пок...
# 99998  человек погиб взрыв неустановлен взрывн устрой...
# 99999  министерств национальн безопасн сша провед рас...
#
# [100000 rows x 1 columns]

# %% [markdown]
# Create the bigrams and trigrams, using gensim:

# %%
text = []
for index, row in preprocessing_data.iterrows():
        text.append(row['text'].split())

from gensim.models import Phrases
bigram = Phrases(text) 
trigram = Phrases(bigram[text])

for idx in range(len(text)):
    for token in bigram[text[idx]]:
        if '_' in token:
            text[idx].append(token)
    for token in trigram[text[idx]]:
        if '_' in token:
            text[idx].append(token)

# %% [markdown]
# Create the bigrams, using nltk:

# %%
texts = []
for index, row in preprocessing_data.iterrows():
        texts.append(row['text'].split())
        
from nltk.util import ngrams
import  collections

bigrams = [ngrams(text, 2) for text in texts]
bigram_freq = [collections.Counter(bigram) for bigram in bigrams]
# look at the most popular bigrams in the third and fourth text
bigram_freq[2].most_common(5), bigram_freq[3].most_common(5)
# Out:
# ([(('нестер', 'погиб'), 2),
#   (('сентябр', '1914'), 2),
#   (('безбрежн', 'неб'), 2),
#   (('неб', 'бескрайн'), 2),
#   (('бескрайн', 'ясн'), 2)],
#  [(('фотографкорреспондент', 'Daily'), 1),
#   (('Daily', 'Mirror'), 1),
#   (('Mirror', 'рассказыва'), 1),
#   (('рассказыва', 'случа'), 1),
#   (('случа', 'котор'), 1)])

# %% [markdown]
# Create LDA-model for 100 000 items.
#
# A more detailed research will be carried out for 10 000 elements, bcs for 100 000 elements it`s take a lot of time.

# %%
from gensim.corpora.dictionary import Dictionary
from numpy import array

dictionary = Dictionary(text)
dictionary.filter_extremes(no_below=10, no_above=0.1)

corpus = [dictionary.doc2bow(doc) for doc in text]
print('Количество уникальных токенов: %d' % len(dictionary))
print('Количество документов: %d' % len(corpus))
# Out:
# Количество уникальных токенов: 84352
# Количество документов: 100000

# %%
from gensim.models.ldamulticore import LdaMulticore

model = LdaMulticore(corpus = corpus, id2word = dictionary, num_topics = 22)
model.show_topics()
# Out:
# [(10,
#   '0.002*"информацион_агентств" + 0.002*"област" + 0.002*"безопасн" + 0.001*"израил" + 0.001*"палестинск" + 0.001*"миллиард_доллар" + 0.001*"территор" + 0.001*"рф" + 0.001*"террорист" + 0.001*"заявлен"'),
#  (6,
#   '0.005*"самолет" + 0.002*"госдум" + 0.002*"закон" + 0.002*"депутат" + 0.001*"московск" + 0.001*"совет" + 0.001*"сторон" + 0.001*"палат" + 0.001*"федеральн" + 0.001*"законопроект"'),
#  (16,
#   '0.002*"чечн" + 0.002*"южн_осет" + 0.002*"здан" + 0.002*"республик" + 0.002*"теракт" + 0.002*"администрац" + 0.002*"боевик" + 0.002*"палестинск" + 0.002*"журналист" + 0.001*"местн"'),
#  (20,
#   '0.003*"взрыв" + 0.003*"пожар" + 0.002*"здан" + 0.002*"взрывн_устройств" + 0.002*"пострада" + 0.002*"обнаруж" + 0.002*"теракт" + 0.002*"служб" + 0.002*"метр" + 0.001*"чечн"'),
#  (5,
#   '0.003*"рубл" + 0.003*"саудовск_арав" + 0.002*"миллиард_рубл" + 0.002*"международн" + 0.002*"боевик" + 0.001*"ирак" + 0.001*"чечн" + 0.001*"банк" + 0.001*"состав" + 0.001*"взрыв"'),
#  (2,
#   '0.003*"милиц" + 0.003*"сотрудник_милиц" + 0.003*"правоохранительн_орган" + 0.002*"задержа" + 0.002*"мест_происшеств" + 0.002*"уголовн" + 0.002*"чечн" + 0.002*"возбужд_уголовн" + 0.002*"правоохранительн" + 0.002*"орган"'),
#  (3,
#   '0.007*"сборн" + 0.007*"матч" + 0.006*"команд" + 0.004*"чемпионат" + 0.004*"счет" + 0.003*"чемпионат_мир" + 0.003*"сборн_росс" + 0.003*"минут" + 0.003*"игр" + 0.002*"побед"'),
#  (1,
#   '0.003*"ядерн" + 0.002*"программ" + 0.002*"отношен" + 0.002*"официальн" + 0.002*"северн_кор" + 0.002*"сторон" + 0.002*"безопасн" + 0.002*"рф" + 0.001*"южн_кор" + 0.001*"южн_осет"'),
#  (19,
#   '0.005*"ирак" + 0.004*"выбор" + 0.003*"процент" + 0.003*"нефт" + 0.003*"парт" + 0.003*"иракск" + 0.002*"доллар_баррел" + 0.002*"цен" + 0.002*"хусейн" + 0.002*"президент_росс"'),
#  (0,
#   '0.008*"фильм" + 0.003*"режиссер" + 0.002*"рол" + 0.002*"главн_рол" + 0.002*"ирак" + 0.002*"картин" + 0.002*"войн" + 0.001*"мир" + 0.001*"книг" + 0.001*"проект"')]

# %%
import pyLDAvis.gensim

lda_display = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-d1d9e2e2220e> in <module>
#       1 import pyLDAvis.gensim
#       2
# ----> 3 lda_display = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
#       4 pyLDAvis.display(lda_display)
#
# c:\program files\python38\lib\site-packages\pyLDAvis\gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     117     """
#     118     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 119     return vis_prepare(**opts)
#
# c:\program files\python38\lib\site-packages\pyLDAvis\_prepare.py in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics)
#     396    term_frequency = np.sum(term_topic_freq, axis=0)
#     397
# --> 398    topic_info         = _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs)
#     399    token_table        = _token_table(topic_info, term_topic_freq, vocab, term_frequency)
#     400    topic_coordinates = _topic_coordinates(mds, topic_term_dists, topic_proportion)
#
# c:\program files\python38\lib\site-packages\pyLDAvis\_prepare.py in _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs)
#     238
#     239    ## compute relevance and top terms for each topic
# --> 240    log_lift = np.log(topic_term_dists / term_proportion)
#     241    log_ttd = np.log(topic_term_dists)
#     242    lambda_seq = np.arange(0, 1 + lambda_step, lambda_step)
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level, fill_value)
#     709             pass_op = op if axis in [0, "columns", None] else na_op
#     710             pass_op = pass_op if not is_logical else op
# --> 711             return _combine_series_frame(
#     712                 self, other, pass_op, fill_value=fill_value, axis=axis, level=level
#     713             )
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\__init__.py in _combine_series_frame(self, other, func, fill_value, axis, level)
#     615         new_data = left._combine_match_index(right, func)
#     616     else:
# --> 617         new_data = dispatch_to_series(left, right, func, axis="columns")
#     618
#     619     return left._construct_result(new_data)
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\__init__.py in dispatch_to_series(left, right, func, str_rep, axis)
#     414         raise NotImplementedError(right)
#     415
# --> 416     new_data = expressions.evaluate(column_op, str_rep, left, right)
#     417     return new_data
#     418
#
# c:\program files\python38\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# c:\program files\python38\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     119
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#     123     return result
#
# c:\program files\python38\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#      72
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\__init__.py in column_op(a, b)
#     402
#     403             def column_op(a, b):
# --> 404                 return {i: func(a.iloc[:, i], b.iloc[i]) for i in range(len(a.columns))}
#     405
#     406     elif isinstance(right, ABCSeries):
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\__init__.py in <dictcomp>(.0)
#     402
#     403             def column_op(a, b):
# --> 404                 return {i: func(a.iloc[:, i], b.iloc[i]) for i in range(len(a.columns))}
#     405
#     406     elif isinstance(right, ABCSeries):
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     500         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     501
# --> 502         return _construct_result(left, result, index=left.index, name=res_name)
#     503
#     504     wrapper.__name__ = op_name
#
# c:\program files\python38\lib\site-packages\pandas\core\ops\__init__.py in _construct_result(left, result, index, name)
#     473     # We do not pass dtype to ensure that the Series constructor
#     474     #  does inference in the case where `result` has object-dtype.
# --> 475     out = left._constructor(result, index=index)
#     476     out = out.__finalize__(left)
#     477
#
# c:\program files\python38\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309         generic.NDFrame.__init__(self, data, fastpath=True)
#     310         self.name = name
# --> 311         self._set_axis(0, index, fastpath=True)
#     312
#     313     def _init_dict(self, data, index=None, dtype=None):
#
# KeyboardInterrupt:

# %%
from gensim.models.coherencemodel import CoherenceModel

def calc_coherence_values(dictionary, corpus, texts, limit, start = 2, step = 2):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = LdaMulticore(corpus=corpus,id2word = dictionary, num_topics = num_topics)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values


model_list, coherence_values = calc_coherence_values(dictionary = dictionary, corpus=corpus, texts=text, start = 2, limit = 41, step = 3)

# %% [markdown]
# We need to define the optimal numbers of topics:

# %%
limit, start, step = 41, 2, 3
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Number of topics")
plt.ylabel("Coherence")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# The best coherence - for ~31 topics.

# %%
from gensim.models import LsiModel

# %%
lsamodel = LsiModel(corpus, num_topics = 22, id2word = dictionary) 
lsamodel.print_topics(num_topics = 22, num_words = 10)
# Out:
# [(0,
#   '0.184*"процент" + 0.089*"ирак" + 0.082*"выбор" + 0.079*"безопасн" + 0.076*"информацион_агентств" + 0.074*"лидер" + 0.074*"совет" + 0.074*"рф" + 0.073*"акц" + 0.073*"закон"'),
#  (1,
#   '0.634*"процент" + 0.132*"рубл" + -0.130*"израильск" + 0.127*"акц" + -0.127*"палестинск" + 0.120*"миллиард" + -0.112*"израил" + 0.107*"выбор" + -0.105*"взрыв" + -0.100*"боевик"'),
#  (2,
#   '0.358*"матч" + 0.326*"сборн" + 0.308*"команд" + 0.194*"счет" + 0.169*"минут" + 0.162*"сборн_росс" + 0.159*"чемпионат" + 0.150*"игр" + 0.142*"мяч" + 0.125*"ворот"'),
#  (3,
#   '-0.292*"палестинск" + -0.269*"израил" + -0.268*"процент" + -0.257*"израильск" + -0.155*"палестинск_автоном" + -0.154*"ирак" + -0.127*"арафат" + 0.123*"уголовн_дел" + -0.120*"сектор_газ" + -0.115*"палестинц"'),
#  (4,
#   '0.382*"процент" + 0.212*"взрыв" + -0.162*"ирак" + 0.145*"получ_ранен" + 0.131*"теракт" + -0.124*"путин" + 0.124*"взрывн_устройств" + 0.123*"ранен" + 0.121*"боевик" + -0.120*"совет"'),
#  (5,
#   '0.328*"выбор" + 0.203*"парт" + -0.188*"ирак" + -0.188*"миллиард" + -0.167*"миллиард_доллар" + 0.151*"кандидат" + -0.141*"фильм" + 0.135*"депутат" + 0.129*"избирательн" + -0.118*"рубл"'),
#  (6,
#   '-0.308*"ирак" + 0.225*"палестинск" + 0.206*"израильск" + 0.192*"израил" + -0.170*"процент" + 0.170*"рубл" + -0.150*"выбор" + 0.137*"миллиард" + -0.136*"иракск" + 0.125*"юкос"'),
#  (7,
#   '0.584*"фильм" + 0.191*"режиссер" + -0.176*"ирак" + -0.158*"чечн" + 0.150*"рол" + 0.128*"главн_рол" + -0.124*"боевик" + 0.106*"картин" + -0.104*"рубл" + -0.101*"миллиард"'),
#  (8,
#   '0.228*"ирак" + -0.211*"путин" + -0.205*"фильм" + 0.169*"адвокат" + -0.168*"президент_росс" + 0.159*"–" + -0.151*"чечн" + -0.145*"рубл" + 0.144*"уголовн_дел" + 0.132*"обвинен"'),
#  (9,
#   '0.926*"–" + 0.091*"тур" + 0.088*"№" + 0.088*"фильм" + 0.079*"сборн_росс" + 0.077*"совет" + -0.061*"счет" + -0.059*"команд" + -0.047*"минут" + 0.047*"крыл"'),
#  (10,
#   '-0.280*"боевик" + -0.280*"фильм" + -0.265*"чечн" + 0.190*"взрыв" + 0.151*"самолет" + -0.143*"процент" + -0.138*"чеченск" + -0.129*"федеральн_сил" + -0.127*"груз" + 0.118*"пострада"'),
#  (11,
#   '0.248*"рубл" + -0.231*"акц" + 0.202*"миллиард_рубл" + -0.192*"самолет" + 0.179*"миллиард" + -0.167*"юкос" + -0.158*"директор" + -0.154*"совет_директор" + -0.135*"совет" + -0.128*"груз"'),
#  (12,
#   '-0.295*"путин" + 0.256*"ирак" + -0.234*"президент_росс" + -0.154*"процент" + 0.139*"миллиард" + 0.135*"совет" + 0.134*"фильм" + 0.132*"иракск" + 0.127*"выбор" + -0.123*"теракт"'),
#  (13,
#   '0.292*"самолет" + -0.206*"взрыв" + -0.197*"теракт" + -0.183*"акц" + 0.152*"груз" + -0.147*"юкос" + -0.144*"взрывн_устройств" + -0.136*"совет" + -0.133*"совет_директор" + 0.126*"член_экипаж"'),
#  (14,
#   '0.391*"нефт" + 0.335*"доллар_баррел" + 0.271*"цен" + 0.229*"баррел" + -0.181*"процент" + 0.176*"цен_нефт" + -0.154*"путин" + 0.144*"опек" + 0.140*"саудовск_арав" + 0.133*"парт"'),
#  (15,
#   '-0.256*"ирак" + 0.245*"миллиард_доллар" + -0.197*"нефт" + 0.172*"миллиард" + -0.170*"доллар_баррел" + -0.149*"путин" + -0.143*"цен" + 0.142*"буш" + 0.138*"джордж_буш" + 0.138*"теракт"'),
#  (16,
#   '-0.413*"груз" + -0.280*"южн_осет" + -0.217*"информацион_агентств" + -0.206*"грузинск" + 0.177*"самолет" + 0.177*"чечн" + -0.146*"президент_груз" + 0.133*"боевик" + -0.129*"аджар" + -0.123*"миллиард_доллар"'),
#  (17,
#   '0.259*"юкос" + 0.226*"информацион_агентств" + 0.213*"миллиард_доллар" + 0.183*"путин" + 0.175*"президент_росс" + 0.172*"джордж_буш" + 0.166*"буш" + 0.155*"миллиард" + -0.146*"закон" + -0.138*"бин_лад"'),
#  (18,
#   '0.311*"ядерн" + 0.239*"северн_кор" + -0.224*"самолет" + 0.179*"программ" + 0.178*"северн_коре" + -0.175*"путин" + 0.174*"ядерн_программ" + 0.169*"оруж" + -0.166*"миллиард_доллар" + 0.157*"северн"'),
#  (19,
#   '-0.260*"информацион_агентств" + -0.193*"рубл" + 0.178*"миллиард_доллар" + -0.154*"фильм" + -0.153*"миллиард_рубл" + 0.151*"парт" + -0.148*"бин_лад" + -0.136*"теракт" + -0.118*"джордж_буш" + 0.118*"мир"'),
#  (20,
#   '0.431*"информацион_агентств" + -0.288*"миллиард_доллар" + 0.216*"рубл" + -0.178*"южн_осет" + 0.173*"информацион" + -0.140*"совет" + 0.115*"нтв" + 0.109*"миллиард_рубл" + -0.107*"юкос" + -0.106*"миллиард"'),
#  (21,
#   '0.350*"миллиард_доллар" + -0.321*"юкос" + -0.217*"южн_осет" + 0.183*"информацион_агентств" + -0.158*"ходорковск" + -0.158*"рубл" + 0.143*"миллиард" + -0.142*"верховн_суд" + -0.138*"закон" + 0.137*"миллион_доллар"')]

# %%
def calc_coherence_values_Lsi(dictionary, corpus, texts, limit, start = 2, step = 2):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = LsiModel(corpus=corpus, id2word = dictionary, num_topics = num_topics)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values


model_list, coherence_values_Lsi = calc_coherence_values(dictionary = dictionary, corpus=corpus, texts=text, start = 2, limit = 41, step =3)

# %%
limit, start, step = 41, 2, 3
x = range(start, limit, step)
plt.plot(x, coherence_values_Lsi)
plt.xlabel("Number of topics")
plt.ylabel("Coherence")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# The best coherence - for ~31 topics.

# %% [markdown]
# - Which one performs better? What metrics were used to evaluate the model?

# %% [markdown]
# - Which one performs better? What metrics were used to evaluate the model?

# %% [markdown]
# LSA performs a little better, bcs its coherence score bigger (about 0.53) then LDA score (about 0.52), but there is no significant difference, and we can say that the models are about the same, bcs they give almost the same quality assessment results for the same number of topics.
#
# Coherence is a metric used to evaluate the quality of a model, based on 'c_v' measure.

# %%
coherence_values_Lsi, coherence_values
# Out:
# ([0.3313809280032163,
#   0.35367600559686607,
#   0.41529608245123006,
#   0.42985194170381996,
#   0.45649970606703955,
#   0.45237161877339543,
#   0.44548079445049094,
#   0.5117705919626421,
#   0.4723137525589643,
#   0.45034221183331913,
#   0.5296252412442826,
#   0.4805576464208803,
#   0.4782927439049513],
#  [0.32489917571221233,
#   0.39126188492079916,
#   0.39514023279843064,
#   0.3902889811761093,
#   0.49693488287692705,
#   0.4878775398825565,
#   0.445974557759936,
#   0.4613846513796985,
#   0.4622536406255051,
#   0.450839031681312,
#   0.5180665382742138,
#   0.45476629427289644,
#   0.4561652370068065])

# %% [markdown]
# Save models for 100 000 items:

# %%
model.save('model_lda.gensim')

# %%
lsamodel.save("model_lsa.gensim")

# %% [markdown]
# Create and explore models for 10 000 items:

# %%
new_preprocessing_data = pd.DataFrame({'text': preprocessing_data['text'][:10000]})
new_preprocessing_data
# Out:
#                                                    text
# 0     бо сопоцкин друскеник законч отступлен германц...
# 1     министерств народн просвещен вид происходя чре...
# 2     штабскапита п н нестер днях увид район желтиев...
# 3     фотографкорреспондент Daily Mirror рассказыва ...
# 4     лиц приеха варшав люблин переда туд доставл «ш...
# ...                                                 ...
# 9995  глав мвд дагеста приказа наряд милиц пригранич...
# 9996  представител кремл ведут активн диалог губерна...
# 9997  москв 20 июл открыва фестивал планет клоунад с...
# 9998  чист американск получ фина уимблдонск теннисн ...
# 9999  перв российск клуб стартова сезон 20002001 евр...
#
# [10000 rows x 1 columns]

# %% [markdown]
# Create N-grams:

# %%
text = []
for index, row in new_preprocessing_data.iterrows():
        text.append(row['text'].split())

from gensim.models import Phrases
bigram = Phrases(text) 
trigram = Phrases(bigram[text])

for idx in range(len(text)):
    for token in bigram[text[idx]]:
        if '_' in token:
            text[idx].append(token)
    for token in trigram[text[idx]]:
        if '_' in token:
            text[idx].append(token)

# %% [markdown]
# Create LDA-model:

# %%
from gensim.corpora.dictionary import Dictionary
from numpy import array

dictionary = Dictionary(text)
dictionary.filter_extremes(no_below=10, no_above=0.1)

corpus = [dictionary.doc2bow(doc) for doc in text]
print('Количество уникальных токенов: %d' % len(dictionary))
print('Количество документов: %d' % len(corpus))
# Out:
# Количество уникальных токенов: 13033
# Количество документов: 10000

# %% [markdown]
# Explore influence of hyperparameters on model quality. First, find optimal number of topics:

# %%
from gensim.models.ldamulticore import LdaMulticore

def calc_coherence_values_new_LDA(dictionary, corpus, texts, limit, start = 2, step = 2):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = LdaMulticore(corpus=corpus,id2word = dictionary, num_topics = num_topics)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values


model_list, coherence_values = calc_coherence_values(dictionary = dictionary, corpus=corpus, texts=text, start = 2, limit = 20, step = 2)
coherence_values
# Out:
# [0.22195553287457542,
#  0.2214482059977975,
#  0.2698429123021306,
#  0.2632510733067798,
#  0.260062732593761,
#  0.23781435354230987,
#  0.25318414973292774,
#  0.26539281857083263,
#  0.25721643383214304]

# %% [markdown]
# Optimal number of topics is 6. Next, change hyperparameter eta and see result:

# %%
def calc_coherence_values_hp(dictionary, corpus, texts, num_topics = 6, eta = [1, 0.01, 0.001, 0.0001, 0.00001]):
    coherence_values = []
    model_list = []
    for eta_value in eta:
        model = LdaMulticore(corpus=corpus,id2word = dictionary, num_topics = num_topics, eta = eta_value)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values


model_list, coherence_values_eta = calc_coherence_values_hp(dictionary = dictionary, corpus=corpus, texts=text)
coherence_values_eta
# Out:
# [0.2588998159379982,
#  0.2425103112827164,
#  0.31763309481732854,
#  0.2508528047568073,
#  0.2306482139631606]

# %% [markdown]
# We can see that LDA-model quality get better if eta = 0.001. The worth res is got if eta = 0.00001.
#
# Next, let`s see how hp alpha influenced on the LDA-model:

# %%
def calc_coherence_values_hp_alpha(dictionary, corpus, texts, num_topics = 6, eta = 0.001):
    coherence_values = []
    model_list = []
    for alpha_value in np.arange(1, 2, 0.1):
        model = LdaMulticore(corpus=corpus,id2word = dictionary, num_topics = num_topics, alpha = alpha_value, eta = eta)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values


model_list, coherence_values_alpha = calc_coherence_values_hp_alpha(dictionary = dictionary, corpus=corpus, texts=text)
coherence_values_alpha
# Out:
# [0.2619557433963509,
#  0.23226196220936143,
#  0.23907352353949177,
#  0.2280282170932669,
#  0.2433490328616176,
#  0.23302033121846752,
#  0.23078463041723718,
#  0.22681671510404797,
#  0.22938811154724928,
#  0.21622134833124926]

# %% [markdown]
# the results got worse. Also researched for alpha=[0, 1], but the result was just as bad.

# %% [markdown]
# For the best LDA model create pyLDAvis display:

# %%
model = LdaMulticore(corpus=corpus,id2word = dictionary, num_topics = 6, eta = 0.001)

lda_display = pyLDAvis.gensim.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el357610770112697764152529469"></div>
# <script type="text/javascript">
#
# var ldavis_el357610770112697764152529469_data = {"mdsDat": {"x": [-0.008773218155272365, -0.004819507313858552, 0.010090445586278059, -0.011059626306480394, 0.02168869067045194, -0.007126784481118714], "y": [0.013280493590032767, -0.0005140776128280921, -0.00045172637134150464, -0.02009831721637678, -0.0016732139260989512, 0.00945684153661258], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [16.54688262939453, 15.610146522521973, 13.976356506347656, 18.308462142944336, 16.668540954589844, 18.88961410522461]}, "tinfo": {"Term": ["\u0441\u043e\u0432\u0435\u0442_\u0444\u0435\u0434\u0435\u0440\u0430\u0446", "\u0441\u0430\u043c\u043e\u043b\u0435\u0442", "\u0438\u0437\u0431\u0438\u0440\u0430\u0442\u0435\u043b\u044c\u043d", "\u0436\u0435\u043b\u0435\u0437\u043d_\u0434\u043e\u0440\u043e\u0433", "\u043f\u0440\u043e\u0446\u0435\u043d\u0442", "\u0431\u043e\u0435\u0432\u0438\u043a", "\u043f\u0443\u0442\u0438\u043d", "\u043a\u0430\u043d\u0434\u0438\u0434\u0430\u0442", "\u0432\u044b\u0431\u043e\u0440", "\u0431\u043e\u0440\u0438\u0441_\u0435\u043b\u044c\u0446\u0438\u043d", "\u0433\u0440\u0443\u0437", "\u0441\u0435\u0432\u0435\u0440\u043d_\u043a\u0430\u0432\u043a\u0430\u0437", "\u0432\u0437\u0440\u044b\u0432", "\u0438\u043d\u0438\u0446\u0438\u0430\u0442\u0438\u0432\u043d_\u0433\u0440\u0443\u043f\u043f", "\u043a\u043e\u043c\u0438\u0441\u0441", "\u043f\u0435\u0440\u0432_\u0432\u0438\u0446\u0435\u043f\u0440\u0435\u043c\u044c\u0435\u0440", "\u0437\u0430\u0432\u043e\u0434", "\u0434\u0435\u043f\u0443\u0442\u0430\u0442_\u0433\u043e\u0441\u0434\u0443\u043c", "\u0434\u043e\u043b\u043b\u0430\u0440_\u0431\u0430\u0440\u0440\u0435\u043b", "\u043b\u0438\u0434\u0435\u0440", "\u0440\u0430_\u0435\u044d\u0441", "\u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a_\u0432\u043e\u0435\u043d", "\u0433\u043b\u0430\u0432_\u0433\u043e\u0441\u0443\u0434\u0430\u0440\u0441\u0442\u0432", "\u043f\u043e\u0436\u0430\u0440", "\u0441\u043e\u0432\u0435\u0442_\u0435\u0432\u0440\u043e\u043f", "\u043c\u0438\u043b\u043b\u0438\u043e\u043d_\u0442\u043e\u043d", "\u043c\u0430\u0442\u0447", "\u0441\u0430\u043d\u043a\u0442\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433", "\u0440\u0443\u0431\u043b", "\u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c", "\u0441\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u0441\u0442\u0432_\u043d\u043e\u0432", "\u043c\u0443\u0440\u043c\u0430\u043d\u0441\u043a_\u043e\u0431\u043b\u0430\u0441\u0442", "\u0445\u043e\u0434_\u043a\u043e\u043d\u0442\u0440\u0442\u0435\u0440\u0440\u043e\u0440\u0438\u0441\u0442\u0438\u0447\u0435\u0441\u043a", "\u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d_\u043a\u0430\u043d\u0446\u043b\u0435\u0440", "\u0441\u0435\u043a\u0446", "\u0433\u043e\u0440\u0430\u0437\u0434_\u043c\u0435\u043d\u044c\u0448", "\u0433\u0443\u0432\u0434_\u0441\u0442\u043e\u043b\u0438\u0446", "\u043d\u0438\u043a\u0430\u043a_\u0432\u0437\u0440\u044b\u0432\u043d", "Airways", "\u043d\u0430\u043f\u0440\u0430\u0432\u043b_\u0440\u0430\u0441\u0441\u043c\u043e\u0442\u0440\u0435\u043d_\u0441\u043e\u0432\u0435\u0442_\u0444\u0435\u0434\u0435\u0440\u0430\u0446", "\u0434\u0435\u043f\u0430\u0440\u0442\u0430\u043c\u0435\u043d\u0442_\u0432\u043d\u0435\u0448\u043d", "\u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d_\u043e\u043a\u0440\u0443\u0433", "\u0434\u0435\u0442\u0441\u043a_\u0441\u0430\u0434", "\u0438\u0441\u0447\u0438\u0441\u043b\u0435\u043d", "\u0432\u0438\u0437\u043e\u0432_\u0440\u0435\u0436", "\u043e\u043a\u0430\u0437\u0430_\u043b\u043e\u0436\u043d", "12_\u0438\u044e\u043d", "\u0444\u0435\u0434\u0435\u0440\u0430\u043b\u044c\u043d_\u044d\u043d\u0435\u0440\u0433\u0435\u0442\u0438\u0447\u0435\u0441\u043a", "\u043f\u0440\u0435\u0434\u043e\u0442\u0432\u0440\u0430\u0449\u0435\u043d_\u0432\u043e\u0437\u043c\u043e\u0436\u043d", "\u0432\u0435_\u043c\u0438\u0440", "\u0448\u0435\u043d\u0433\u0435\u043d\u0441\u043a", "\u043a\u0430\u0442\u0430\u043d", "\u0435\u0432\u0440\u043e\u043f\u0435\u0439\u0441\u043a_\u043a\u043e\u043c\u0438\u0441\u0441" ...

# %% [markdown]
# At the pic we can see bubles approximately the same size, it means that topics are distributed about the same.
# Also, topics are scattered throughout the diagram and have virtually no overlap, it means that LDA topic model is good.
#
# Picture:

# %% [markdown]
# ![LDA_for_10%20000.png](attachment:LDA_for_10%20000.png)

# %% [markdown]
# Create LSI-vodel for 10 000 items:

# %%
lsamodel = LsiModel(corpus, num_topics = 6, id2word = dictionary) 
lsamodel.print_topics(num_topics = 6, num_words = 10)
# Out:
# [(0,
#   '-0.135*"выбор" + -0.130*"процент" + -0.116*"путин" + -0.104*"закон" + -0.097*"рубл" + -0.096*"боевик" + -0.081*"председател" + -0.079*"совет" + -0.078*"депутат" + -0.077*"российск_федерац"'),
#  (1,
#   '-0.348*"боевик" + -0.294*"федеральн_сил" + -0.169*"населен_пункт" + -0.168*"войск" + -0.163*"северн_кавказ" + -0.162*"грозн" + 0.154*"выбор" + -0.154*"чеченск" + 0.148*"процент" + -0.133*"группировк"'),
#  (2,
#   '0.309*"выбор" + 0.200*"избирательн" + 0.184*"кандидат" + -0.154*"миллион_доллар" + -0.147*"рубл" + -0.145*"миллиард_доллар" + -0.140*"миллиард" + -0.138*"банк" + 0.135*"депутат" + 0.116*"госдум"'),
#  (3,
#   '-0.377*"процент" + -0.375*"рубл" + 0.179*"сайт" + -0.173*"миллиард_рубл" + -0.138*"миллиард" + -0.131*"боевик" + 0.128*"интернет" + -0.128*"федеральн_сил" + -0.112*"миллион_рубл" + -0.106*"цен"'),
#  (4,
#   '0.418*"российск_федерац" + 0.245*"федерац" + 0.237*"путин" + -0.194*"выбор" + -0.191*"процент" + 0.178*"президент_росс" + -0.149*"сайт" + 0.148*"борис_ельцин" + 0.147*"совет_федерац" + -0.140*"избирательн"'),
#  (5,
#   '-0.471*"российск_федерац" + 0.288*"путин" + -0.227*"федерац" + -0.179*"закон" + 0.171*"борис_ельцин" + 0.164*"президент_росс" + 0.148*"встреч" + 0.130*"глав_государств" + -0.118*"сайт" + 0.118*"процент"')]

# %%
def calc_coherence_values_new_Lsi(dictionary, corpus, texts, limit, start = 2, step = 2):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = LsiModel(corpus=corpus, id2word = dictionary, num_topics = num_topics)
        model_list.append(model)
        coherencemodel = CoherenceModel(model = model, texts = texts, dictionary = dictionary, coherence = 'c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values


model_list, coherence_values_Lsi = calc_coherence_values(dictionary = dictionary, corpus=corpus, texts=text, start = 2, limit = 20, step = 2)
coherence_values_Lsi
# Out:
# [0.20666613377272297,
#  0.25146910882207596,
#  0.2378880769695552,
#  0.25541333010771583,
#  0.27144056300371744,
#  0.25676077790091184,
#  0.27549534301110257,
#  0.2793164086237269,
#  0.25062980404878465]

# %%
limit, start, step = 20, 2, 2
x = range(start, limit, step)
plt.plot(x, coherence_values_Lsi)
plt.xlabel("Number of topics")
plt.ylabel("Coherence")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %% [markdown]
# With hyperparameter tuning, the LDA model performed better than the LSA model.
